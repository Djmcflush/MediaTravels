# %%
import pandas as pd
import numpy as np

# %%
cast_df = pd.read_csv("/Users/proyardie/data/NETFLIX/Data/IMDB/IMDB.csv")

# %%
actors = cast_df['Actors']

# %%
unique = {f: True for f in actors}

# %%
actors = list(unique.keys())

# %%
print(actors)
# Out:
# ['Chris Pratt', ' Vin Diesel', ' Bradley Cooper', ' Zoe Saldana', 'Noomi Rapace', ' Logan Marshall-Green', ' Michael Fassbender', ' Charlize Theron', 'James McAvoy', ' Anya Taylor-Joy', ' Haley Lu Richardson', ' Jessica Sula', 'Matthew McConaughey', 'Reese Witherspoon', ' Seth MacFarlane', ' Scarlett Johansson', 'Will Smith', ' Jared Leto', ' Margot Robbie', ' Viola Davis', 'Matt Damon', ' Tian Jing', ' Willem Dafoe', ' Andy Lau', 'Ryan Gosling', ' Emma Stone', ' Rosemarie DeWitt', ' J.K. Simmons', 'Essie Davis', ' Andrea Riseborough', ' Julian Barratt', 'Kenneth Branagh', 'Charlie Hunnam', ' Robert Pattinson', ' Sienna Miller', ' Tom Holland', 'Jennifer Lawrence', ' Chris Pratt', ' Michael Sheen', 'Laurence Fishburne', 'Eddie Redmayne', ' Katherine Waterston', ' Alison Sudol', 'Dan Fogler', 'Taraji P. Henson', ' Octavia Spencer', ' Janelle Monáe', 'Kevin Costner', 'Felicity Jones', ' Diego Luna', ' Alan Tudyk', ' Donnie Yen', "Auli'i Cravalho", ' Dwayne Johnson', ' Rachel House', ' 
# ...

# %%
import twitter

# %%
api = twitter.Api(consumer_key='tj9P8ZOF7Bjy4Osao8mGabrPR',
                      consumer_secret='uElikexH6F5n3NnlLm87yKe9yh6ohYrMfeO4MjP54LakUO2sJT',
                      access_token_key='375937198-1pQQGhxEmQru6Wboxo0Gf89D8wXuEfQSDUYz4DHT',
                      access_token_secret='qcxFA1JjV8ngZs54h7r4IprGHX9IP03NRTOgz0bhsXrBs',
                      sleep_on_rate_limit=True)

# %%
Academey = {}
for each in actors:
    Academey[each] = api.GetUsersSearch(term=each,count=2)

# %%
print(Academey)
# Out:
# {'Chris Pratt': [User(ID=241382835, ScreenName=prattprattpratt), User(ID=25029409, ScreenName=ShaneHartline), User(ID=557783747, ScreenName=zenjiro2), User(ID=11586702, ScreenName=Anna_Banana), User(ID=1085637368386736128, ScreenName=MovieTheKid), User(ID=1044047490985734145, ScreenName=cprattnews), User(ID=734082854, ScreenName=chrispratt23), User(ID=85049696, ScreenName=alexjvasquez), User(ID=22743546, ScreenName=Crispyrat), User(ID=178822400, ScreenName=thwwiww)], ' Vin Diesel': [User(ID=3061977469, ScreenName=vindiesel), User(ID=44296009, ScreenName=angrynate), User(ID=285517935, ScreenName=msswiggy), User(ID=1461342943, ScreenName=Jacob_deNobel), User(ID=29960511, ScreenName=ron_im_iz), User(ID=10557112, ScreenName=thecuriosity), User(ID=1482985014, ScreenName=VinDieselFan2), User(ID=57804524, ScreenName=minionsareNICE), User(ID=52169648, ScreenName=TimKeckForever), User(ID=330419526, ScreenName=patrick_ren)], ' Bradley Cooper': [User(ID=1419103585, ScreenName=BradleyC_Fan), Use
# ...

# %%
user_names =
