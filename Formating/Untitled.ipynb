# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/Users/proyardie/data/NETFLIX'

# %%
scripts_path= os.getcwd() + '/Data'
os.listdir(scripts_path)
# Out:
# ['China Yearly Box Office',
#  '.DS_Store',
#  'baby-names.csv',
#  'Production_budget',
#  'Scripts',
#  'IMDB']

# %%
df = pd.read_csv(scripts_path + '/Scripts/Script_dataset.csv')

# %%
df.head(2)
# Out:
#                         Unnamed: 0  day_scenes  night_scenes  ext_scenes  \
# 0  4630237/Script_Training Day.txt          51            14          27
# 1                The Rage Carrie 2          48            64          56
#
#    interior_scenes  fade_count  descriptive_words  dialogue_percentage  \
# 0               47           2                920             0.658647
# 1               59          16               1781             0.713085
#
#     exposition_percentage  lines_of_dialogue  lines_of_exposition  \
# 0                0.341353                438                  227
# 1                0.286915                594                  239
#
#    avg_length_of_dialogue  avg_length_of_exposition  \
# 0               37.102740                 47.607930
# 1               52.678451                 78.916318
#
#                                  most_common  \
# 0  [('THE', 73), ('NIGHT', 64), ('INT', 59)]
# 1  [('THE', 73), ('NIGHT', 64), ('INT', 59)]
#
# ...

# %%
df = df.iloc[1:]
most_common = df.iloc[1]['most_common']

# %%
df.head(1)
# Out:
#           Unnamed: 0  day_scenes  night_scenes  ext_scenes  interior_scenes  \
# 1  The Rage Carrie 2          48            64          56               59
#
#    fade_count  descriptive_words  dialogue_percentage   exposition_percentage  \
# 1          16               1781             0.713085                0.286915
#
#    lines_of_dialogue  lines_of_exposition  avg_length_of_dialogue  \
# 1                594                  239               52.678451
#
#    avg_length_of_exposition                                most_common  \
# 1                 78.916318  [('THE', 73), ('NIGHT', 64), ('INT', 59)]
#
#                                                words  \
# 1  Counter({'THE': 73, 'NIGHT': 64, 'INT': 59, 'E...
#
#                                       expostion_text  \
# 1  ['THE STREET - FROM ABOVE - NIGHT A light rain...
#
#                                       Dialoguge_text  \
# 1  ['CARRIE II Written by Rafael Moreu 13 FEBRUAR...
#
# ...

# %%
df = df.drop(columns="most_common")

# %%
df.head(1)
# Out:
#           Unnamed: 0  day_scenes  night_scenes  ext_scenes  interior_scenes  \
# 1  The Rage Carrie 2          48            64          56               59
#
#    fade_count  descriptive_words  dialogue_percentage   exposition_percentage  \
# 1          16               1781             0.713085                0.286915
#
#    lines_of_dialogue  lines_of_exposition  avg_length_of_dialogue  \
# 1                594                  239               52.678451
#
#    avg_length_of_exposition  \
# 1                 78.916318
#
#                                                words  \
# 1  Counter({'THE': 73, 'NIGHT': 64, 'INT': 59, 'E...
#
#                                       expostion_text  \
# 1  ['THE STREET - FROM ABOVE - NIGHT A light rain...
#
#                                       Dialoguge_text  \
# 1  ['CARRIE II Written by Rafael Moreu 13 FEBRUAR...
#
#                                         misscilenous
# 1  ["BARBARA's still painting the wall in the bac...

# %%
import collections

words = df['words']
words.head(1)
print(type(words))
s={'THE': 73, 'NIGHT': 64, 'INT': 59, 'EXT': 56, 'DAY': 48, 'TO': 42, 'HOUSE': 25, 'WALSH': 23, 'SCHOOL': 19, 'TEACHER': 19, 'IN': 18, 'FADE': 16, 'ROOM': 16, 'ENGLISH': 16, 'TV': 16, 'CAR': 15, 'ON': 15, 'BACK': 13, 'FOOTBALL': 13, 'OF': 12, 'STARK': 12, 'BLACK': 11, 'HAND': 11, 'CUT': 11, 'BEAT
'SQUEAL': 1, 'SCOOPS': 1, 'HEADLIGHTS': 1, 'LIGHTS': 1, 'WINDSHIELD': 1, 'CRACKS': 1, 'PLEASE': 1, 'PET': 1, 'CLINIC': 1, 'FEMALE': 1, 'WAITING': 1, 'NIG': 1, 'THREE': 1, 'PATRONS': 1, 'WEL': 1, 'HEARTBEAT': 1, 'EDGES': 1, 'FALLS': 1, 'DAZED': 1, 'LOW': 1, 'LUNCH': 1, 'COLD': 1, 'TAKEN': 1, 'ABACK': 1, 'DKNY': 1, 'PLACE': 1, 'BARKING': 1, 'CHANT': 1, 'LADIES': 1, 'ANGRY': 1, 'TOILET': 1, 'PAPER': 1, 'FRONT': 1, 'WEAKLY': 1, 'KNOCKING': 1, 'HANDLE': 1, 'JIGGLES': 1, 'FILTERED': 1, 'CELL': 1, 'SHADOW': 1, 'VOICES': 1, 'UT': 1, 'PARLOR': 1, 'YELL': 1, 'WAGON': 1, 'SE': 1, 'OPERATOR': 1, 'EMI': 1, 'WEID': 1, 'NE': 1, 'DEVIL': 1, 'RAW': 1, 'EGGS': 1, 'SLOWLY': 1, 'FRUSTRATED': 1, 'THOUGHTS': 1, 'FUCK': 1, 'THIS': 1, 'EXP': 1, 'DES': 1, 'RACBZL': 1, 'EBT': 1, 'CAY': 1, 'SHOWERS': 1, 'GRAFFITI': 1, 'KI': 1, 'KILL': 1, 'SHOUTS': 1, 'CHROME': 1, 'CHAIR': 1, 'DISTORTED': 1, 'REFLECTION': 1, 'PUBLIC': 1, 'MICROFILM': 1, 'MACHINE': 1, 'STREAM': 1, 'NEWSPAPER': 1, 'CHAMBERLAIN': 1, 'RECORDER': 1, 'RIK': 1, 'ITE': 1, 'MATRON': 1, 'BI': 1, 'CERTIFICATE': 1, 'MOTHER': 1, 'FATHER': 1, 'WN': 1, 'UNKNO': 1, 'ARKHAII': 1, 'WHISPERS': 1, 'NURSES': 1, 'SO': 1, 'BARBAR': 1, 'DESPERATELY': 1, 'GROPING': 1, 'MINIATURE': 1, 'GOLF': 1, 'COURSE': 1, 'USED': 1, 'HURST': 1, 'RACH': 1, 'EXHALES': 1, 'SITS': 1, 'FORWARD': 1, 'JE': 1, 'SEE': 1, 'RASE': 1, 'GOTHIC': 1, 'BED': 1, 'HANDS': 1, 'SCREAMS': 1, 'PLAYFUL': 1, 'DREAM': 1, 'LIKE': 1, 'GLIDE': 1, 'PROM': 1, 'STOCK': 1, 'STROBING': 1, 'SIGHS': 1, 'DISTRICT': 1, 'ATTORNEYS': 1, 'DUSK': 1, 'TRANSGRESSIONS': 1, 'NODS': 1, 'BUT': 1, 'SHOPPING': 1, 'MALL': 1, 'DEPARTMENT': 1, 'STORE': 1, 'SALES': 1, 'MAN': 1, 'BY': 1, 'SLIP': 1, 'DRESS': 1, 'DAISIES': 1, 'TROPHY': 1, 'MARBLE': 1, 'CLOSEUPS': 1, 'ASLEEP': 1, 'FIND': 1, 'MI': 1, 'MICROPHONE': 1, 'CORD': 1, 'CAMERA': 1, 'DIVE': 1, 'PUPIL': 1, 'EYE': 1, 'SERIES': 1, 'DISSOLVES': 1, 'FINALLY': 1, 'DRY': 1, 'ALN': 1, 'TUNNEL': 1, 'BALL': 1, 'FUMBLES': 1, 'OPPOSING': 1, 'LINEMAN': 1, 'RUNNING': 1, 'HALF': 1, 'TIME': 1, 'QUARTERBACK': 1, 'FOURTH': 1, 'QUARTER': 1, 'DEFENSIVE': 1, 'BACKS': 1, 'HOMETOWN': 1, 'TICKING': 1, 'TICK': 1, 'FLASHES': 1, 'SIDELINE': 1, 'PHOTOGRAPHER': 1, 'WARMLY': 1, 'INCH': 1, 'WIDEN': 1, 'YOUNGER': 1, 'APISI': 1, 'REVEAL': 1, 'CAN': 1, 'WIPING': 1, 'PLAYING': 1, 'BEHIND': 1, 'INTERTWINED': 1, 'BODIES': 1, 'CHEERLEADING': 1, 'JESSES': 1, 'MAKING': 1, 'CK': 1, 'NIGHTMARISH': 1, 'GALLERY': 1, 'FACES': 1, 'MOUTHS': 1, 'INTERCUT': 1, 'WITH': 1, 'UPS': 1, 'POUNDS': 1, 'SCREW': 1, 'CLOSES': 1, 'LOOKING': 1, 'GLASS': 1, 'RATTLE': 1, 'CRACK': 1, 'BURST': 1, 'SHADOWS': 1, 'BA': 1, 'IRON': 1, 'FIREPLACE': 1, 'POKER': 1, 'MY': 1, 'PEOPLE': 1, 'PULSE': 1, 'LIQUOR': 1, 'BOTTLES': 1, 'FLAMING': 1, 'CHAOS': 1, 'DEN': 1, 'HANDGUN': 1, 'GARDEN': 1, 'HOSE': 1, 'GUNSHOTS': 1, 'FIRES': 1, 'BLOODY': 1, 'ARM': 1, 'UNDERWATER': 1, 'SURFACE': 1, 'COYER': 1, 'RX': 1, 'TEN': 1, 'CRYING': 1, 'STARRY': 1, 'BLAZING': 1, 'CHUNK': 1, 'COUGHS': 1, 'PUSH': 1, 'BACKYARD': 1, 'SHE': 1, 'SEES': 1, 'CEILING': 1, 'HURTS': 1, 'LIGHT': 1, 'CRICKETS': 1, 'SUP': 1, 'DAMS': 1, 'LINIVER': 1, 'STTY': 1, 'QNE': 1, 'FAD': 1, 'DAM': 1, 'UNIVERSITY': 1, 'CHURCH': 1, 'BUILDING': 1, 'MOVING': 1, 'MIDNIGHT': 1, 'FIGURE': 1, 'FLIES': 1, 'IS': 1, 'NIGH': 1, 'LOUD': 1, 'FATIM': 1, 'JOS': 1, 'DIGITAL': 1, 'DOORSN': 1, 'BEATING': 1, 'WILDLY': 1, 'HEARTBEATS': 1, 'LQ': 1, 'MULTIPLIED': 1, 'INFINITY': 1}
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.head(3)
# Out:
#           Unnamed: 0  day_scenes  night_scenes  ext_scenes  interior_scenes  \
# 1  The Rage Carrie 2          48            64          56               59
# 2       Training Day          51            14          27               47
# 3    Thelma & Louise         147            60         108              134
#
#    fade_count  descriptive_words  dialogue_percentage   exposition_percentage  \
# 1          16               1781             0.713085                0.286915
# 2           2                920             0.658647                0.341353
# 3           4               1240             0.730570                0.269430
#
#    lines_of_dialogue  lines_of_exposition  avg_length_of_dialogue  \
# 1                594                  239               52.678451
# 2                438                  227               37.102740
# 3                423                  156               49.354610
#
#    avg_length_of_exposition  \
# 1                 78.916318
# ...

# %%
predicates = ['THE','IT','A','AN', 'AND','THEM', 'THESE','THEM', 'INT','EXT', 'IN','FADE','TOO','TO','ON','PUT','OF','ITS']
data = []
type(words)
w = words.values
for x in range(0, 2):
    print(type(w[x]))
# Out:
# <class 'str'>
# <class 'str'>

# %%
df.to_csv()
