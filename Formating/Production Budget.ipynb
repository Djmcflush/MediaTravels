# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/Users/proyardie/data/NETFLIX'

# %%
cd Data/
# Out:
# /Users/proyardie/data/NETFLIX/Data

# %%
df1 = pd.read_csv('Production_Budget/Sheet 1.csv')
df2 = pd.read_csv('Production_Budget/Sheet 2.csv')
df3 = pd.read_csv('Production_Budget/Sheet 3.csv')
df4 = pd.read_csv('Production_Budget/Sheet 4.csv')
df5 = pd.read_csv('Production_Budget/Sheet 5.csv')

# %%
df1.

# %%
df = pd.concat([df1,df2])
# Out:
# /Users/proyardie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df= pd.concat([df,df3])
df= pd.concat([df,df4])
df= pd.concat([df,df5])
# Out:
# /Users/proyardie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# /Users/proyardie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# /Users/proyardie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# ...

# %%
df = df.drop('Unnamed: 5',1)

# %%
df = df.drop('Unnamed: 0',1)

# %%
df.sort_values('Worldwide Gross', ascending=False)
# Out:
#    Domestic Gross                                              Movie  \
# 82    $77,233,467                          Where the Wild Things Are
# 6        $311,434                              Jin líng shí san chai
# 63   $317,871,467              Harry Potter and the Sorcerer’s Stone
# 98    $35,497,337                                         Green Zone
# 38   $404,508,916                     Jumanji: Welcome to the Jungle
# 7    $309,420,425           Pirates of the Caribbean: At World’s End
# 97   $364,001,123                                    The Jungle Book
# 64   $296,131,568       Harry Potter and the Deathly Hallows: Part I
# 20   $258,366,855                The Hobbit: The Desolation of Smaug
# 87    $59,475,623                                 The Stepford Wives
# 93    $48,417,850                                          Peter Pan
# 21   $255,119,788          The Hobbit: The Battle of the Five Armies
# 22    $44,114,232                                   The Lovely Bones
# ...

# %%
df.to_csv('Production_Budget/ProductionBudget.csv')
